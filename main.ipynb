# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks

os.chdir('./OCTA-journal')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pip install --upgrade pip
# !pip uninstall scikit-image
# !pip install scikit-image==0.19.0
import skimage
print(skimage.__version__)
# skimage 0.19.0 is compulsory

# !pip install tensorboardX
# !pip install phasepack
# !pip install pyfftw
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Found existing installation: scikit-image 0.19.3
# Uninstalling scikit-image-0.19.3:
#   Would remove:
#     /usr/local/bin/skivi
#     /usr/local/lib/python3.10/dist-packages/doc/ext/*
#     /usr/local/lib/python3.10/dist-packages/scikit_image-0.19.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scikit_image.libs/libgomp-a34b3233.so.1.0.0
#     /usr/local/lib/python3.10/dist-packages/skimage/*
# Proceed (Y/n)? y
#   Successfully uninstalled scikit-image-0.19.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 25.6 MB/s eta 0:00:00
# ...
# 0.19.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# References:
# pytorch_wavelets: https://github.com/fbcotter/pytorch_wavelets

# %cd ./pytorch_wavelets/
# !pip install .
# %cd ../
# Out:
# /content/drive/MyDrive/Colab Notebooks/OCTA-journal/pytorch_wavelets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/Colab Notebooks/OCTA-journal/pytorch_wavelets
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytorch-wavelets: filename=pytorch_wavelets-1.3.0-py3-none-any.whl size=131405 sha256=608c7ad743fd7265d06b23824489e75307adc0dba0cad32b8634516c82f7075c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dgzueo3z/wheels/5a/a9/12/305c0e8cd192f049ad0b847aa2b5f7aab5077ecd9e74d34fbb
# Successfully built pytorch-wavelets
# ...
# /content/drive/MyDrive/Colab Notebooks/OCTA-journal

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python train.py --n_epochs 30 --l2h_hb 9 --l2h_lb 11 --h2l_hb 3 --h2l_lb 7 --dis_iter 4
# Out:
# Namespace(epoch=0, n_epochs=30, batchSize=1, dataroot='./dataset/train', whole_dir='./dataset/evalution_6mm/parts', pretrained_root='./pre_trained/netG_A2B_pretrained.pth', pretrained=False, log_dir_train='./logs/tensorboard/train/', log_dir_test='./logs/tensorboard/test/', log='0', B2A=False, lr=0.0002, decay_epoch=20, sizeA=256, sizeB=256, n_layers=5, dis_size=6, n_downsampling=2, input_nc=1, output_nc=1, cuda=False, n_cpu=2, dis_iter=4, seed=3074, beta1=10.0, beta2=10.0, beta3=5.0, beta4=5.0, beta5=1.0, beta6=1.0, beta7=1.0, l2h_hb=9, l2h_lb=11, h2l_hb=3, h2l_lb=7)
# # FS type: gau, kernel size=5
# # FS type: gau, kernel size=5
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# 241
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# Epoch (1/30) Finished
# 100% 297/297 [00:54<00:00,  5.42it/s]
#  PSNR: 17.4356 SSIM: 0.4767 MSE: 0.0729 NMI: 1.0554 FSIM: 0.8910
# ...

# %% [markdown]
# previous best

# %%
# !python train.py --n_epochs 30 --l2h_hb 9 --l2h_lb 11 --h2l_hb 3 --h2l_lb 7 --dis_iter 4
# Out:
# Namespace(B2A=False, batchSize=1, beta1=10.0, beta2=10.0, beta3=5.0, beta4=5.0, beta5=1.0, beta6=1.0, beta7=1.0, cuda=False, dataroot='./dataset/train', decay_epoch=20, dis_iter=4, dis_size=6, epoch=0, h2l_hb=3, h2l_lb=7, input_nc=1, l2h_hb=9, l2h_lb=11, log='0', log_dir_test='./logs/tensorboard/test/', log_dir_train='./logs/tensorboard/train/', lr=0.0002, n_cpu=2, n_downsampling=2, n_epochs=30, n_layers=5, output_nc=1, pretrained=False, pretrained_root='./pre_trained/netG_A2B_pretrained.pth', seed=3074, sizeA=256, sizeB=256, whole_dir='./dataset/evalution_6mm/parts')
# # FS type: gau, kernel size=5
# # FS type: gau, kernel size=5
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# 241
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# Epoch (1/30) Finished
# 100% 297/297 [01:40<00:00,  2.97it/s]
#  PSNR: 17.4519 SSIM: 0.4839 MSE: 0.0728 NMI: 1.0575 FSIM: 0.8877
# ...

# %%
# !python train.py --n_epochs 100 --l2h_hb 7 --l2h_lb 11 --h2l_hb 3 --h2l_lb 5 --dis_iter 4
# Out:
# Namespace(B2A=False, batchSize=1, beta1=10.0, beta2=10.0, beta3=5.0, beta4=5.0, beta5=1.0, beta6=1.0, beta7=1.0, cuda=False, dataroot='./dataset/train', decay_epoch=20, dis_iter=4, dis_size=6, epoch=0, h2l_hb=3, h2l_lb=5, input_nc=1, l2h_hb=7, l2h_lb=11, log='0', log_dir_test='./logs/tensorboard/test/', log_dir_train='./logs/tensorboard/train/', lr=0.0002, n_cpu=2, n_downsampling=2, n_epochs=100, n_layers=5, output_nc=1, pretrained=False, pretrained_root='./pre_trained/netG_A2B_pretrained.pth', seed=3074, sizeA=256, sizeB=256, whole_dir='./dataset/evalution_6mm/parts')
# # FS type: gau, kernel size=5
# # FS type: gau, kernel size=5
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# 241
# Adjusting learning rate of group 0 to 2.0000e-04.
# Adjusting learning rate of group 0 to 2.0000e-04.
# Epoch (1/100) Finished
# 100% 297/297 [00:23<00:00, 12.79it/s]
#  PSNR: 17.1653 SSIM: 0.4523 MSE: 0.0779 NMI: 1.0551 FSIM: 0.8700
# ...

# %%
# !python train.py --decay_epoch 30 --pretrained False --n_epochs 55 --lr 2e-4 --scheduler False --beta1 0 --seed 3407 --l2h_hb 15 --l2h_lb 20 --h2l_hb 1 --h2l_lb 5 --n_downsampling 0
# Out:
# Namespace(B2A=False, batchSize=1, beta1=0.0, beta2=10.0, beta3=2.0, beta4=0.5, beta5=0.5, cuda=False, dataroot='./dataset/train', decay_epoch=30, dis_size=6, epoch=0, h2l_hb=1, h2l_lb=5, input_nc=1, l2h_hb=15, l2h_lb=20, log='0', log_dir_test='./logs/tensorboard/test/', log_dir_train='./logs/tensorboard/train/', lr=0.0002, n_cpu=2, n_downsampling=0, n_epochs=55, n_layers=5, output_nc=1, pretrained=True, pretrained_root='./pre_trained/netG_A2B_pretrained.pth', scheduler=True, seed=3407, sizeA=256, sizeB=256, whole_dir='./dataset/evalution_6mm/parts')
# # FS type: gau, kernel size=5
# # FS type: gau, kernel size=5
# ...
# Layer (type:depth-idx)                                                                                    Param #
# ...
# NetworkA2B                                                                                                --
# ├─UnetGenerator: 1-1                                                                                      --
# ...
